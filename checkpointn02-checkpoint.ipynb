# %%
#1ere question
liste = [i for i in range(2000, 3201) if i % 7 == 0 if i % 5 != 0] 
print(liste)


#2eme question
nmbr=int(input("entrez un nombre pour voir son factoriel"))
factoriel=1
if num < 0:
   print("math erreur ")
elif num == 0:
   print("le factoriel de 0 égale à 1")
else:
   for i in range(1,num + 1):
       factoriel = factoriel*i
   print("le factoriel de",num,"=",factorial)


#3eme question
racine=int(input("entrer un nombre"))
racine_carré={i:i*i for i in range (1,racine+1)}
print(racine_carré)

#4eme question
str=input("entrer un string")
indx=int(input("entrer l'index"))
nv_str=str[:indx-1]+str[indx:]
print(nv_str)


#5eme question
import numpy as np
print("enter the dimension of ure array")
size = int(input()) 
print("enter the elements")
array_input = []
for x in range(size):
    array_input.append([int(y) for y in input().split()])
print(array_input)

arr = np.array(array_input)

print(f'NumPy Array:\n{arr}')

list1 = arr.tolist()

print(f'List: {list1}')

#6eme question
import numpy as np

x = np.array([0, 1, 2])
y = np.array([2, 1, 0])

print("nOriginal array1:")
print(x)
print("nOriginal array1:")
print(y)
print("nCovariance matrix of the said arrays:n",np.cov(x, y))

#7eme question 
import math
c=50
h=30
print("enter the values")
value =[]
items=[x for x in input().split(',')]
for d in items:
    value.append(str(int(round(math.sqrt(2*c*float(d)/h)))))
print("the results are as the following values, meaning first value with first result ect")
print(','.join(value))
